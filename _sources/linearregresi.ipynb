# %% [markdown]
# # LiniearRegresi

# %%
from sklearn.datasets import make_regression
from matplotlib import pyplot
x_test, y_test = make_regression(n_samples=100, n_features=1, noise=2)
pyplot.scatter(x_test,y_test)
pyplot.show()

# %%
x_test[0]
# Out:
# array([-0.49032773])

# %%
from sklearn import linear_model
from sklearn.linear_model import LinearRegression
import numpy as np
reg = linear_model.LinearRegression()
reg.fit(x_test,y_test)
LinearRegression()
reg.coef_
reg.intercept_
# Out:
# -0.13291784710999188

# %%
import pandas as pd
data={'X':x_test.tolist(),"y":y_test.tolist()}
df=pd.DataFrame(data)
df
# Out:
#                          X           y
# 0    [-0.4903277309286439]  -42.343117
# 1     [1.7827067403713899]  138.150409
# 2    [-0.2650240398923365]  -22.121228
# 3   [-0.00578254884112137]    0.014176
# 4     [-0.746937916866369]  -57.952797
# ..                     ...         ...
# 95    [-1.139852829413889]  -88.538002
# 96   [-1.5619552548120328] -117.982037
# 97    [-1.317812673465891] -106.388912
# 98    [-1.305800421591408] -102.845605
# 99   [-1.1562091013807485]  -90.849610
#
# [100 rows x 2 columns]
