# %% [markdown]
# # Tugas 1

# %% [markdown]
# ## read data wthi url

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('https://raw.githubusercontent.com/CSSEGISandData/COVID-19_Unified-Dataset/master/COVID-19_LUT.csv')

# %%
dataa = pd.read_csv('http://data.gresikkab.go.id/dataset/9c28b29c-56c9-441c-889f-46e847afc448/resource/50528cd6-f09e-409b-b34f-2beabb4ebdb1/download/4.2.13-banyaknya-permintaan-darah-menurut-jenis-golongan-darah-dikabupaten-gresik-2018.csv',sep=";")

# %%
dataa
# Out:
#                   Bulan    A    B    0   AB  Jumlah Total
# 0       Januari/January  350  488  670   77          1585
# 1     Februari/February  318  515  620   88          1541
# 2           Maret/March  345  514  811   83          1753
# 3           April/April  343  426  621   94          1484
# 4               Mei/May  380  566  731   94          1771
# 5             Juni/June  305  373  565   74          1317
# 6             Juli/July  465  587  958  107          2117
# 7        Agustus/August  325  544  750  120          1739
# 8   September/September  315  483  666   74          1538
# 9       Oktober/October  399  404  646   90          1539
# 10    November/November  384  513  794  113          1804
# 11    Desember/December  507  663  884  103          2157

# %% [markdown]
# ## median

# %%
st.median(dataa['Jumlah Total'])
# Out:
# 1662.0

# %% [markdown]
# ## mean

# %%
st.mean(dataa['Jumlah Total'])
# Out:
# 1695.4166666666667

# %% [markdown]
# ## modus

# %%
st.mode(dataa['Jumlah Total'])
# Out:
# ---------------------------------------------------------------------------
# StatisticsError                           Traceback (most recent call last)
# <ipython-input-55-f5dd61466d1e> in <module>
# ----> 1 st.mode(dataa['Jumlah Total'])
#
# /usr/lib/python3.7/statistics.py in mode(data)
#     504     elif table:
#     505         raise StatisticsError(
# --> 506                 'no unique mode; found %d equally common values' % len(table)
#     507                 )
#     508     else:
#
# StatisticsError: no unique mode; found 12 equally common values

# %% [markdown]
# terjadi error karena tidak terdapat modus atau nilai yang sering muncul

# %% [markdown]
# ## Skewed/Kemiringan

# %%
plt.figure()
sns.distplot(dataa['Jumlah Total'])
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
plt.figure(figsize=(15,6))
plt.plot(dataa['Bulan'],dataa['A'])
plt.plot(dataa['Bulan'],dataa['B'])
plt.plot(dataa['Bulan'],dataa['0'])
plt.plot(dataa['Bulan'],dataa['AB'])
plt.xticks(rotation = 'vertical')
plt.legend(["A",'B','0','AB'])
plt.show()

# %%
plt.scatter(dataa['Bulan'], dataa['A'])
plt.title("Golongan darah A")
# dataa.plot(kind='line',figsize=(10,6))
plt.ylabel('Jumlah')
plt.xlabel('Bulan')
plt.show()

# %%
type(dataa)
# Out:
# pandas.core.frame.DataFrame

# %%
df_dataa = pd.DataFrame(dataa)

# %%
A = 0
B = 0
O = 0
AB = 0
data_sum = 0
for i in range(len(df_dataa)):
    A += df_dataa.iloc[i][1]
    B += df_dataa.iloc[i][2]
    O += df_dataa.iloc[i][3]
    AB += df_dataa.iloc[i][4]
print(A)
print(B)
print(O)
print(AB)
# Out:
# 4436
# 6076
# 8716
# 1117

# %%
dataa
# Out:
#                   Bulan    A    B    0   AB  Jumlah Total
# 0       Januari/January  350  488  670   77          1585
# 1     Februari/February  318  515  620   88          1541
# 2           Maret/March  345  514  811   83          1753
# 3           April/April  343  426  621   94          1484
# 4               Mei/May  380  566  731   94          1771
# 5             Juni/June  305  373  565   74          1317
# 6             Juli/July  465  587  958  107          2117
# 7        Agustus/August  325  544  750  120          1739
# 8   September/September  315  483  666   74          1538
# 9       Oktober/October  399  404  646   90          1539
# 10    November/November  384  513  794  113          1804
# 11    Desember/December  507  663  884  103          2157

# %%
import statistics as st

# %%
import urllib
url = 'https://katalog.satudata.go.id/api/3/action/datastore_search?resource_id=3c59f2f1-2d2e-4a11-ba8e-2ceb0904563e&limit=5&q=title:jones'  
fileobj = urllib.request.urlopen(url)
print(fileobj.read())
# Out:
# b'{"help": "https://katalog.satudata.go.id/api/3/action/help_show?name=datastore_search", "success": true, "result": {"include_total": true, "limit": 5, "q": "title:jones", "records_format": "objects", "resource_id": "3c59f2f1-2d2e-4a11-ba8e-2ceb0904563e", "total_estimation_threshold": null, "records": [], "fields": [{"id": "_id", "type": "int"}, {"id": "Data Status Gizi balita Desa Sengon tahun 2019", "type": "text"}, {"id": "rank", "type": "float"}], "_links": {"start": "/api/3/action/datastore_search?resource_id=3c59f2f1-2d2e-4a11-ba8e-2ceb0904563e&limit=5&q=title%3Ajones", "next": "/api/3/action/datastore_search?resource_id=3c59f2f1-2d2e-4a11-ba8e-2ceb0904563e&limit=5&q=title%3Ajones&offset=5"}, "total": 0, "total_was_estimated": false}}'

# %% [markdown]
# # percobaan lainnya

# %%
import seaborn as sns

# %% [markdown]
# # cara yt 1

# %%
dataa
# Out:
#                   Bulan    A    B    0   AB  Jumlah Total
# 0       Januari/January  350  488  670   77          1585
# 1     Februari/February  318  515  620   88          1541
# 2           Maret/March  345  514  811   83          1753
# 3           April/April  343  426  621   94          1484
# 4               Mei/May  380  566  731   94          1771
# 5             Juni/June  305  373  565   74          1317
# 6             Juli/July  465  587  958  107          2117
# 7        Agustus/August  325  544  750  120          1739
# 8   September/September  315  483  666   74          1538
# 9       Oktober/October  399  404  646   90          1539
# 10    November/November  384  513  794  113          1804
# 11    Desember/December  507  663  884  103          2157

# %%
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
